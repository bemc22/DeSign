# %%
COLAB = True

if COLAB:
  from google.colab import drive
  drive.mount('/content/drive', force_remount=True)
  local_path = '/content/drive/My Drive/hdsp/proyectos/BNN'
else:
  local_path = r'./'

import os

os.chdir(local_path)
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow_addons

# %%
import os
import tensorflow as tf
import numpy as np
import tensorflow_addons as tfa
from binarynet.main import build_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from models.layers  import Threshold2D, Threshold3D
from data.Dataset import load_cifar, load_stl10, load_cifar100

tf.random.set_seed(2224)


BATCH_SIZE = 180
DATASET = "cifar"
MODE =  None

DATA_AUGMENTATION = dict(
    augment = True,
)


DATASETS = {
    "cifar": load_cifar,
    "stl10": load_stl10,
    "cifar100": load_cifar100,
}

if DATASET == "cifar":
    NUM_CLASSES = 10
elif DATASET == "stl10":
    NUM_CLASSES = 10
elif DATASET == "cifar100":
    NUM_CLASSES = 100


load_fun = DATASETS[DATASET]

train_ds, test_ds = load_fun(batch_size=BATCH_SIZE, num_classes=NUM_CLASSES, **DATA_AUGMENTATION)


EXPERIMENT_ID = 0
EPOCHS = 3
LR_START = 1e-2
LR_END = 1e-4
OPTIMIZER = Adam

K_decay = np.log(LR_END / LR_START) * (1 / EPOCHS)
M_decay = ( LR_END - LR_START) / EPOCHS
B_decay = LR_START

F1_score = tfa.metrics.F1Score(num_classes=10, threshold=None)
optimizer = OPTIMIZER(LR_START)

def exp_decay(epoch, lr):
    print("actual learning_rate: ", lr)
    return LR_START*np.exp(K_decay*epoch)

def lineal_decay(epoch, lr):
    print("actual learning_rate: ", lr)
    return B_decay + M_decay*epoch

lr_decay = tf.keras.callbacks.LearningRateScheduler(lineal_decay)

PESOS_PATH = f'./pesos/binary_relu_{DATASET}_{MODE}_best.tf'
PESOS_LAST_PATH = f'./pesos/binary_relu_{DATASET}_{MODE}_last.tf'

callbacks = [
             ModelCheckpoint(PESOS_PATH, monitor='val_accuracy', save_best_only=True,
              save_weights_only=True, mode='max', verbose=1), lr_decay
]


THRESH_MODES = {
    'threshold3d': Threshold3D,
    'threshold2d': Threshold2D,
    None: None,
}


KERNEL_FILENAME = 'threshold_2x2x4_shifting_n1_right_v1.mat'
KERNEL_PATH = f'./thresholds/{KERNEL_FILENAME}'

KERNEL_FILENAME ="random"
KERNEL_PATH = KERNEL_FILENAME

threshold_layer = THRESH_MODES[MODE]


model = build_model(size=32, kernel_filename=KERNEL_PATH, threshold_layer=threshold_layer)

model.compile(optimizer=optimizer, loss='squared_hinge', metrics=['accuracy', F1_score])
model.summary()

history = model.fit( train_ds , epochs=EPOCHS, validation_data=test_ds, callbacks=callbacks)
model.save_weights(PESOS_LAST_PATH)

print("LAST WEIGTHS")
print("TESTING PERFORMANCE")
model.evaluate(test_ds)
print('')

model.load_weights(PESOS_PATH)

print("BEST WEIGTHS")
print("TESTING PERFORMANCE")
model.evaluate(test_ds)
print('')
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# QUANTIZER FUNCTION LOADED
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# NEW NORMALIZATION SCHEME
# LOG_SOFTMAX ENABLE
# Model: "BinaryNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d__binary_layer (Conv2D_B  (None, 32, 32, 128)  3584       ['input_1[0][0]']
#  inaryLayer)
#
#  batch_normalization (BatchNorm  (None, 32, 32, 128)  512        ['conv2d__binary_layer[0][0]']
#  alization)
#
#  tf.__operators__.add (TFOpLamb  (None, 32, 32, 128)  0          ['batch_normalization[0][0]']
#  da)
#
#  tf.math.truediv (TFOpLambda)   (None, 32, 32, 128)  0           ['tf.__operators__.add[0][0]']
#
#  tf.clip_by_value (TFOpLambda)  (None, 32, 32, 128)  0           ['tf.math.truediv[0][0]']
#
#  tf.math.round (TFOpLambda)     (None, 32, 32, 128)  0           ['tf.clip_by_value[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 32, 32, 128)  0           ['tf.math.round[0][0]',
#                                                                   'tf.clip_by_value[0][0]']
#
#  tf.stop_gradient (TFOpLambda)  (None, 32, 32, 128)  0           ['tf.math.subtract[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 32, 32, 128)  0          ['tf.clip_by_value[0][0]',
#  mbda)                                                            'tf.stop_gradient[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 32, 32, 128)  0           ['tf.__operators__.add_1[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 32, 32, 128)  0          ['tf.math.multiply[0][0]']
#  )
#
#  conv2d__binary_layer_1 (Conv2D  (None, 32, 32, 128)  147584     ['tf.math.subtract_1[0][0]']
#  _BinaryLayer)
#
#  max_pooling2d (MaxPooling2D)   (None, 16, 16, 128)  0           ['conv2d__binary_layer_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 128)  512        ['max_pooling2d[0][0]']
#  rmalization)
#
#  tf.__operators__.add_2 (TFOpLa  (None, 16, 16, 128)  0          ['batch_normalization_1[0][0]']
#  mbda)
#
#  tf.math.truediv_1 (TFOpLambda)  (None, 16, 16, 128)  0          ['tf.__operators__.add_2[0][0]']
#
#  tf.clip_by_value_1 (TFOpLambda  (None, 16, 16, 128)  0          ['tf.math.truediv_1[0][0]']
#  )
#
#  tf.math.round_1 (TFOpLambda)   (None, 16, 16, 128)  0           ['tf.clip_by_value_1[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 16, 16, 128)  0          ['tf.math.round_1[0][0]',
#  )                                                                'tf.clip_by_value_1[0][0]']
#
#  tf.stop_gradient_1 (TFOpLambda  (None, 16, 16, 128)  0          ['tf.math.subtract_2[0][0]']
#  )
#
#  tf.__operators__.add_3 (TFOpLa  (None, 16, 16, 128)  0          ['tf.clip_by_value_1[0][0]',
#  mbda)                                                            'tf.stop_gradient_1[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 16, 16, 128)  0          ['tf.__operators__.add_3[0][0]']
#  )
#
#  tf.math.subtract_3 (TFOpLambda  (None, 16, 16, 128)  0          ['tf.math.multiply_1[0][0]']
#  )
#
#  conv2d__binary_layer_2 (Conv2D  (None, 16, 16, 256)  295168     ['tf.math.subtract_3[0][0]']
#  _BinaryLayer)
#
#  batch_normalization_2 (BatchNo  (None, 16, 16, 256)  1024       ['conv2d__binary_layer_2[0][0]']
#  rmalization)
#
#  tf.__operators__.add_4 (TFOpLa  (None, 16, 16, 256)  0          ['batch_normalization_2[0][0]']
#  mbda)
#
#  tf.math.truediv_2 (TFOpLambda)  (None, 16, 16, 256)  0          ['tf.__operators__.add_4[0][0]']
#
#  tf.clip_by_value_2 (TFOpLambda  (None, 16, 16, 256)  0          ['tf.math.truediv_2[0][0]']
#  )
#
#  tf.math.round_2 (TFOpLambda)   (None, 16, 16, 256)  0           ['tf.clip_by_value_2[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 16, 16, 256)  0          ['tf.math.round_2[0][0]',
#  )                                                                'tf.clip_by_value_2[0][0]']
#
#  tf.stop_gradient_2 (TFOpLambda  (None, 16, 16, 256)  0          ['tf.math.subtract_4[0][0]']
#  )
#
#  tf.__operators__.add_5 (TFOpLa  (None, 16, 16, 256)  0          ['tf.clip_by_value_2[0][0]',
#  mbda)                                                            'tf.stop_gradient_2[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 16, 16, 256)  0          ['tf.__operators__.add_5[0][0]']
#  )
#
#  tf.math.subtract_5 (TFOpLambda  (None, 16, 16, 256)  0          ['tf.math.multiply_2[0][0]']
#  )
#
#  conv2d__binary_layer_3 (Conv2D  (None, 16, 16, 256)  590080     ['tf.math.subtract_5[0][0]']
#  _BinaryLayer)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 256)   0           ['conv2d__binary_layer_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 256)   1024        ['max_pooling2d_1[0][0]']
#  rmalization)
#
#  tf.__operators__.add_6 (TFOpLa  (None, 8, 8, 256)   0           ['batch_normalization_3[0][0]']
#  mbda)
#
#  tf.math.truediv_3 (TFOpLambda)  (None, 8, 8, 256)   0           ['tf.__operators__.add_6[0][0]']
#
#  tf.clip_by_value_3 (TFOpLambda  (None, 8, 8, 256)   0           ['tf.math.truediv_3[0][0]']
#  )
#
#  tf.math.round_3 (TFOpLambda)   (None, 8, 8, 256)    0           ['tf.clip_by_value_3[0][0]']
#
#  tf.math.subtract_6 (TFOpLambda  (None, 8, 8, 256)   0           ['tf.math.round_3[0][0]',
#  )                                                                'tf.clip_by_value_3[0][0]']
#
#  tf.stop_gradient_3 (TFOpLambda  (None, 8, 8, 256)   0           ['tf.math.subtract_6[0][0]']
#  )
#
#  tf.__operators__.add_7 (TFOpLa  (None, 8, 8, 256)   0           ['tf.clip_by_value_3[0][0]',
#  mbda)                                                            'tf.stop_gradient_3[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 8, 8, 256)   0           ['tf.__operators__.add_7[0][0]']
#  )
#
#  tf.math.subtract_7 (TFOpLambda  (None, 8, 8, 256)   0           ['tf.math.multiply_3[0][0]']
#  )
#
#  conv2d__binary_layer_4 (Conv2D  (None, 8, 8, 512)   1180160     ['tf.math.subtract_7[0][0]']
#  _BinaryLayer)
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 512)   2048        ['conv2d__binary_layer_4[0][0]']
#  rmalization)
#
#  tf.__operators__.add_8 (TFOpLa  (None, 8, 8, 512)   0           ['batch_normalization_4[0][0]']
#  mbda)
#
#  tf.math.truediv_4 (TFOpLambda)  (None, 8, 8, 512)   0           ['tf.__operators__.add_8[0][0]']
#
#  tf.clip_by_value_4 (TFOpLambda  (None, 8, 8, 512)   0           ['tf.math.truediv_4[0][0]']
#  )
#
#  tf.math.round_4 (TFOpLambda)   (None, 8, 8, 512)    0           ['tf.clip_by_value_4[0][0]']
#
#  tf.math.subtract_8 (TFOpLambda  (None, 8, 8, 512)   0           ['tf.math.round_4[0][0]',
#  )                                                                'tf.clip_by_value_4[0][0]']
#
#  tf.stop_gradient_4 (TFOpLambda  (None, 8, 8, 512)   0           ['tf.math.subtract_8[0][0]']
#  )
#
#  tf.__operators__.add_9 (TFOpLa  (None, 8, 8, 512)   0           ['tf.clip_by_value_4[0][0]',
#  mbda)                                                            'tf.stop_gradient_4[0][0]']
#
#  tf.math.multiply_4 (TFOpLambda  (None, 8, 8, 512)   0           ['tf.__operators__.add_9[0][0]']
#  )
#
#  tf.math.subtract_9 (TFOpLambda  (None, 8, 8, 512)   0           ['tf.math.multiply_4[0][0]']
#  )
#
#  conv2d__binary_layer_5 (Conv2D  (None, 8, 8, 512)   2359808     ['tf.math.subtract_9[0][0]']
#  _BinaryLayer)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 512)   0           ['conv2d__binary_layer_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 4, 4, 512)   2048        ['max_pooling2d_2[0][0]']
#  rmalization)
#
#  tf.__operators__.add_10 (TFOpL  (None, 4, 4, 512)   0           ['batch_normalization_5[0][0]']
#  ambda)
#
#  tf.math.truediv_5 (TFOpLambda)  (None, 4, 4, 512)   0           ['tf.__operators__.add_10[0][0]']
#
#  tf.clip_by_value_5 (TFOpLambda  (None, 4, 4, 512)   0           ['tf.math.truediv_5[0][0]']
#  )
#
#  tf.math.round_5 (TFOpLambda)   (None, 4, 4, 512)    0           ['tf.clip_by_value_5[0][0]']
#
#  tf.math.subtract_10 (TFOpLambd  (None, 4, 4, 512)   0           ['tf.math.round_5[0][0]',
#  a)                                                               'tf.clip_by_value_5[0][0]']
#
#  tf.stop_gradient_5 (TFOpLambda  (None, 4, 4, 512)   0           ['tf.math.subtract_10[0][0]']
#  )
#
#  tf.__operators__.add_11 (TFOpL  (None, 4, 4, 512)   0           ['tf.clip_by_value_5[0][0]',
#  ambda)                                                           'tf.stop_gradient_5[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 4, 4, 512)   0           ['tf.__operators__.add_11[0][0]']
#  )
#
#  tf.math.subtract_11 (TFOpLambd  (None, 4, 4, 512)   0           ['tf.math.multiply_5[0][0]']
#  a)
#
#  flatten (Flatten)              (None, 8192)         0           ['tf.math.subtract_11[0][0]']
#
#  dense__binary_layer (Dense_Bin  (None, 1024)        8389632     ['flatten[0][0]']
#  aryLayer)
#
#  batch_normalization_6 (BatchNo  (None, 1024)        4096        ['dense__binary_layer[0][0]']
#  rmalization)
#
#  tf.__operators__.add_12 (TFOpL  (None, 1024)        0           ['batch_normalization_6[0][0]']
#  ambda)
#
#  tf.math.truediv_6 (TFOpLambda)  (None, 1024)        0           ['tf.__operators__.add_12[0][0]']
#
#  tf.clip_by_value_6 (TFOpLambda  (None, 1024)        0           ['tf.math.truediv_6[0][0]']
#  )
#
#  tf.math.round_6 (TFOpLambda)   (None, 1024)         0           ['tf.clip_by_value_6[0][0]']
#
#  tf.math.subtract_12 (TFOpLambd  (None, 1024)        0           ['tf.math.round_6[0][0]',
#  a)                                                               'tf.clip_by_value_6[0][0]']
#
#  tf.stop_gradient_6 (TFOpLambda  (None, 1024)        0           ['tf.math.subtract_12[0][0]']
#  )
#
#  tf.__operators__.add_13 (TFOpL  (None, 1024)        0           ['tf.clip_by_value_6[0][0]',
#  ambda)                                                           'tf.stop_gradient_6[0][0]']
#
#  tf.math.multiply_6 (TFOpLambda  (None, 1024)        0           ['tf.__operators__.add_13[0][0]']
#  )
#
#  tf.math.subtract_13 (TFOpLambd  (None, 1024)        0           ['tf.math.multiply_6[0][0]']
#  a)
#
#  dense__binary_layer_1 (Dense_B  (None, 1024)        1049600     ['tf.math.subtract_13[0][0]']
#  inaryLayer)
#
#  batch_normalization_7 (BatchNo  (None, 1024)        4096        ['dense__binary_layer_1[0][0]']
#  rmalization)
#
#  tf.__operators__.add_14 (TFOpL  (None, 1024)        0           ['batch_normalization_7[0][0]']
#  ambda)
#
#  tf.math.truediv_7 (TFOpLambda)  (None, 1024)        0           ['tf.__operators__.add_14[0][0]']
#
#  tf.clip_by_value_7 (TFOpLambda  (None, 1024)        0           ['tf.math.truediv_7[0][0]']
#  )
#
#  tf.math.round_7 (TFOpLambda)   (None, 1024)         0           ['tf.clip_by_value_7[0][0]']
#
#  tf.math.subtract_14 (TFOpLambd  (None, 1024)        0           ['tf.math.round_7[0][0]',
#  a)                                                               'tf.clip_by_value_7[0][0]']
#
#  tf.stop_gradient_7 (TFOpLambda  (None, 1024)        0           ['tf.math.subtract_14[0][0]']
#  )
#
#  tf.__operators__.add_15 (TFOpL  (None, 1024)        0           ['tf.clip_by_value_7[0][0]',
#  ambda)                                                           'tf.stop_gradient_7[0][0]']
#
#  tf.math.multiply_7 (TFOpLambda  (None, 1024)        0           ['tf.__operators__.add_15[0][0]']
#  )
#
#  tf.math.subtract_15 (TFOpLambd  (None, 1024)        0           ['tf.math.multiply_7[0][0]']
#  a)
#
#  dense__binary_layer_2 (Dense_B  (None, 10)          10250       ['tf.math.subtract_15[0][0]']
#  inaryLayer)
#
#  batch_normalization_8 (BatchNo  (None, 10)          40          ['dense__binary_layer_2[0][0]']
#  rmalization)
#
#  tf.nn.log_softmax (TFOpLambda)  (None, 10)          0           ['batch_normalization_8[0][0]']
#
# ==================================================================================================
# Total params: 14,041,266
# Trainable params: 14,033,566
# Non-trainable params: 7,700
# __________________________________________________________________________________________________
# actual learning_rate:  0.009999999776482582
# Epoch 1/3
# 278/278 [==============================] - ETA: 0s - loss: 0.7837 - accuracy: 0.3968 - f1_score: 0.3920
# Epoch 1: val_accuracy improved from -inf to 0.51020, saving model to ./pesos/binary_relu_cifar_None_best.tf
# 278/278 [==============================] - 80s 202ms/step - loss: 0.7837 - accuracy: 0.3968 - f1_score: 0.3920 - val_loss: 0.6338 - val_accuracy: 0.5102 - val_f1_score: 0.5060 - lr: 0.0100
# actual learning_rate:  0.009999999776482582
# Epoch 2/3
# 278/278 [==============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.5135 - f1_score: 0.5103
# Epoch 2: val_accuracy improved from 0.51020 to 0.58130, saving model to ./pesos/binary_relu_cifar_None_best.tf
# 278/278 [==============================] - 49s 176ms/step - loss: 0.6331 - accuracy: 0.5135 - f1_score: 0.5103 - val_loss: 0.5565 - val_accuracy: 0.5813 - val_f1_score: 0.5795 - lr: 0.0067
# actual learning_rate:  0.0066999997943639755
# Epoch 3/3
# 278/278 [==============================] - ETA: 0s - loss: 0.5651 - accuracy: 0.5729 - f1_score: 0.5705
# Epoch 3: val_accuracy improved from 0.58130 to 0.62540, saving model to ./pesos/binary_relu_cifar_None_best.tf
# 278/278 [==============================] - 50s 179ms/step - loss: 0.5651 - accuracy: 0.5729 - f1_score: 0.5705 - val_loss: 0.5154 - val_accuracy: 0.6254 - val_f1_score: 0.6224 - lr: 0.0034
# LAST WEIGTHS
# TESTING PERFORMANCE
# 56/56 [==============================] - 3s 57ms/step - loss: 0.5154 - accuracy: 0.6254 - f1_score: 0.6224
#
# BEST WEIGTHS
# TESTING PERFORMANCE
# 56/56 [==============================] - 3s 56ms/step - loss: 0.5154 - accuracy: 0.6254 - f1_score: 0.6224
